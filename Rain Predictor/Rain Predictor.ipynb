# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('weatherAUS.csv')

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
# 3          NE           24.0         SE  ...        16.0       1017.6
# 4           W           41.0        ENE  ...        33.0       1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142193 entries, 0 to 142192
# Data columns (total 24 columns):
# Date             142193 non-null object
# Location         142193 non-null object
# MinTemp          141556 non-null float64
# MaxTemp          141871 non-null float64
# Rainfall         140787 non-null float64
# Evaporation      81350 non-null float64
# Sunshine         74377 non-null float64
# WindGustDir      132863 non-null object
# WindGustSpeed    132923 non-null float64
# WindDir9am       132180 non-null object
# WindDir3pm       138415 non-null object
# WindSpeed9am     140845 non-null float64
# WindSpeed3pm     139563 non-null float64
# Humidity9am      140419 non-null float64
# Humidity3pm      138583 non-null float64
# Pressure9am      128179 non-null float64
# Pressure3pm      128212 non-null float64
# Cloud9am         88536 non-null float64
# Cloud3pm         85099 non-null float64
# Temp9am          141289 non-null float64
# ...

# %%
df[df['Rainfall']>100]
# Out:
#               Date       Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 1142    2012-03-01         Albury     17.1     20.9     104.2          NaN
# 4395    2013-01-29  BadgerysCreek     18.3     28.1     116.0          NaN
# 5571    2016-06-05  BadgerysCreek     14.5     18.1     100.2          NaN
# 5572    2016-06-06  BadgerysCreek     13.4     17.7     109.2          NaN
# 8974    2009-02-17   CoffsHarbour     19.9     27.1     189.0          NaN
# 9225    2009-10-27   CoffsHarbour     17.3     21.0     141.8          NaN
# 9236    2009-11-07   CoffsHarbour     17.4     23.1     371.0          NaN
# 9567    2010-10-04   CoffsHarbour     16.2     19.5     128.0          0.2
# 9626    2010-12-02   CoffsHarbour     19.6     24.0     105.4          NaN
# 9661    2011-01-06   CoffsHarbour     18.0     20.8     102.0          NaN
# 9789    2011-06-13   CoffsHarbour     12.6     18.2     103.4          NaN
# ...

# %%
rainfall=[0.6]
for i in df['RISK_MM']:
    rainfall.append(i)
df['Rainfall']=pd.DataFrame(rainfall)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142193 entries, 0 to 142192
# Data columns (total 24 columns):
# Date             142193 non-null object
# Location         142193 non-null object
# MinTemp          141556 non-null float64
# MaxTemp          141871 non-null float64
# Rainfall         142193 non-null float64
# Evaporation      81350 non-null float64
# Sunshine         74377 non-null float64
# WindGustDir      132863 non-null object
# WindGustSpeed    132923 non-null float64
# WindDir9am       132180 non-null object
# WindDir3pm       138415 non-null object
# WindSpeed9am     140845 non-null float64
# WindSpeed3pm     139563 non-null float64
# Humidity9am      140419 non-null float64
# Humidity3pm      138583 non-null float64
# Pressure9am      128179 non-null float64
# Pressure3pm      128212 non-null float64
# Cloud9am         88536 non-null float64
# Cloud3pm         85099 non-null float64
# Temp9am          141289 non-null float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
df['RainTomorrow']=label.fit_transform(df['RainTomorrow'])

# %%
df.drop(columns='RainToday',inplace=True)

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  141556.000000  141871.000000  142193.000000  81350.000000
# mean       12.186400      23.226784       2.360686      5.469824
# std         6.403283       7.117618       8.477968      4.188537
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.800000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  74377.000000  132923.000000  140845.000000  139563.000000
# mean       7.624853      39.984292      14.001988      18.637576
# std        3.781525      13.588801       8.893337       8.803345
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
df['Location'].unique()
# Out:
# array(['Albury', 'BadgerysCreek', 'Cobar', 'CoffsHarbour', 'Moree',
#        'Newcastle', 'NorahHead', 'NorfolkIsland', 'Penrith', 'Richmond',
#        'Sydney', 'SydneyAirport', 'WaggaWagga', 'Williamtown',
#        'Wollongong', 'Canberra', 'Tuggeranong', 'MountGinini', 'Ballarat',
#        'Bendigo', 'Sale', 'MelbourneAirport', 'Melbourne', 'Mildura',
#        'Nhil', 'Portland', 'Watsonia', 'Dartmoor', 'Brisbane', 'Cairns',
#        'GoldCoast', 'Townsville', 'Adelaide', 'MountGambier', 'Nuriootpa',
#        'Woomera', 'Albany', 'Witchcliffe', 'PearceRAAF', 'PerthAirport',
#        'Perth', 'SalmonGums', 'Walpole', 'Hobart', 'Launceston',
#        'AliceSprings', 'Darwin', 'Katherine', 'Uluru'], dtype=object)

# %%
df_albury=df[df['Location']=='Albury']
df_newcastle=df[df['Location']=='Newcastle']
df_brisbane=df[df['Location']=='Brisbane']
df_perth=df[df['Location']=='Perth']
df_sydney=df[df['Location']=='Sydney']
df_darwin=df[df['Location']=='Darwin']
df_katherine=df[df['Location']=='Katherine']

# %%
df_albury.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RISK_MM  \
# ...

# %%
df_albury.describe()
# Out:
#            MinTemp      MaxTemp     Rainfall  Evaporation  Sunshine  \
# count  3005.000000  3010.000000  3011.000000          0.0       0.0
# mean      9.520899    22.630963     1.914115          NaN       NaN
# std       6.062028     7.796728     6.230014          NaN       NaN
# min      -2.800000     6.800000     0.000000          NaN       NaN
# 25%       4.700000    15.800000     0.000000          NaN       NaN
# 50%       9.100000    21.900000     0.000000          NaN       NaN
# 75%      14.300000    28.900000     0.400000          NaN       NaN
# max      28.300000    44.800000   104.200000          NaN       NaN
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count    3001.000000   3007.000000   3004.000000  3007.000000  3007.000000
# mean       32.953016      8.221816     14.378828    74.108081    47.884935
# std        13.362165      6.744532      7.196747    17.437693    19.833037
# ...

# %%
df_albury.drop(columns=['Evaporation','Sunshine','Cloud9am','Cloud3pm'],inplace=True)
# Out:
# C:\Users\Cornelis\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
df_albury.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed  \
# 0  2008-12-01   Albury     13.4     22.9       0.6           W           44.0
# 1  2008-12-02   Albury      7.4     25.1       0.0         WNW           44.0
# 2  2008-12-03   Albury     12.9     25.7       0.0         WSW           46.0
# 3  2008-12-04   Albury      9.2     28.0       0.0          NE           24.0
# 4  2008-12-05   Albury     17.5     32.3       1.0           W           41.0
#
#   WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0          W        WNW          20.0          24.0         71.0         22.0
# 1        NNW        WSW           4.0          22.0         44.0         25.0
# 2          W        WSW          19.0          26.0         38.0         30.0
# 3         SE          E          11.0           9.0         45.0         16.0
# 4        ENE         NW           7.0          20.0         82.0         33.0
#
# ...

# %%
data_num = [num for num in df_albury.columns if df_albury[num].dtype!='O']
data_obj = [num for num in df_albury.columns if df_albury[num].dtype=='O']

# %%
for i in df_albury[data_num].drop(columns=['RainTomorrow']).columns:
    plt.figure(figsize=(10,6))
    sns.boxplot(data=df_albury,x='RainTomorrow',y=i)
    plt.show

# %%
df_albury[data_num].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3011 entries, 0 to 3010
# Data columns (total 14 columns):
# MinTemp          3005 non-null float64
# MaxTemp          3010 non-null float64
# Rainfall         3011 non-null float64
# WindGustSpeed    3001 non-null float64
# WindSpeed9am     3007 non-null float64
# WindSpeed3pm     3004 non-null float64
# Humidity9am      3007 non-null float64
# Humidity3pm      3007 non-null float64
# Pressure9am      3011 non-null float64
# Pressure3pm      3007 non-null float64
# Temp9am          3007 non-null float64
# Temp3pm          3007 non-null float64
# RISK_MM          3011 non-null float64
# RainTomorrow     3011 non-null int32
# dtypes: float64(13), int32(1)
# memory usage: 421.1 KB

# %%
df_albury[df_albury['MinTemp'].isna()]
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall WindGustDir  \
# 282   2009-09-11   Albury      NaN     18.8       0.0           N
# 439   2010-02-18   Albury      NaN     31.2       0.0         ESE
# 447   2010-02-27   Albury      NaN     26.3       0.0          NE
# 452   2010-03-05   Albury      NaN     22.3       0.0          NE
# 603   2010-08-05   Albury      NaN     11.8       0.0         WSW
# 1667  2013-10-11   Albury      NaN     18.5       0.0           W
#
#       WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 282            31.0         SE        NNE           7.0          19.0
# 439            31.0        SSE        SSW           7.0           7.0
# 447            26.0         SE          E           9.0          13.0
# 452            37.0         NE         NE          24.0          17.0
# 603            28.0          N        WNW           2.0          19.0
# 1667           37.0          W        WNW          17.0          17.0
#
# ...

# %%
ad = df_albury['MaxTemp']-df_albury['Temp3pm']
ad.mean()
# Out:
# 1.2661676646706586

# %%
ad = df_albury['Temp9am']-df_albury['MinTemp']
ad.mean()
# Out:
# 4.825724758413857

# %%
mask = df_albury['MinTemp'].isna() 
ind = df_albury['MinTemp'].loc[mask].index
for i in ind:
    df_albury['MinTemp'].loc[i] = df_albury['Temp9am'].loc[i]
# Out:
# C:\Users\Cornelis\Anaconda3\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\Cornelis\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
ind
# Out:
# Int64Index([282, 439, 447, 452, 603, 1667], dtype='int64')

# %%
df_albury['MinTemp'].loc[282]
# Out:
# 8.7

# %%
df_albury['Temp9am'].loc[282]
# Out:
# 8.7

# %%
mask = df_albury['MaxTemp'].isna() 
ind = df_albury['MaxTemp'].loc[mask].index
for i in ind:
    df_albury['MaxTemp'].loc[i] = df_albury['Temp3pm'].loc[i]
# Out:
# C:\Users\Cornelis\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
mask = df_albury['Temp3pm'].isna() 
ind = df_albury['Temp3pm'].loc[mask].index
for i in ind:
    df_albury['Temp3pm'].loc[i] = df_albury['MaxTemp'].loc[i]
# Out:
# C:\Users\Cornelis\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
mask = df_albury['Temp9am'].isna() 
ind = df_albury['Temp9am'].loc[mask].index
for i in ind:
    df_albury['Temp9am'].loc[i] = df_albury['MinTemp'].loc[i]
# Out:
# C:\Users\Cornelis\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df_albury.isna().sum()
# Out:
# Date               0
# Location           0
# MinTemp            0
# MaxTemp            0
# Rainfall           0
# WindGustDir       10
# WindGustSpeed     10
# WindDir9am       517
# WindDir3pm        42
# WindSpeed9am       4
# WindSpeed3pm       7
# Humidity9am        4
# Humidity3pm        4
# Pressure9am        0
# Pressure3pm        4
# Temp9am            0
# Temp3pm            0
# RISK_MM            0
# RainTomorrow       0
# dtype: int64

# %%
df_albury[data_num].head(10)
# Out:
#    MinTemp  MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  WindSpeed3pm  \
# 0     13.4     22.9       0.6           44.0          20.0          24.0
# 1      7.4     25.1       0.0           44.0           4.0          22.0
# 2     12.9     25.7       0.0           46.0          19.0          26.0
# 3      9.2     28.0       0.0           24.0          11.0           9.0
# 4     17.5     32.3       1.0           41.0           7.0          20.0
# 5     14.6     29.7       0.2           56.0          19.0          24.0
# 6     14.3     25.0       0.0           50.0          20.0          24.0
# 7      7.7     26.7       0.0           35.0           6.0          17.0
# 8      9.7     31.9       0.0           80.0           7.0          28.0
# 9     13.1     30.1       1.4           28.0          15.0          11.0
#
#    Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Temp9am  Temp3pm  \
# 0         71.0         22.0       1007.7       1007.1     16.9     21.8
# ...

# %%
df_albury['WindGustDir'].fillna(df_albury['WindGustDir'].mode(),inplace=True)
df_albury['WindGustSpeed'].fillna(df_albury['WindGustSpeed'].median(),inplace=True)
df_albury['WindDir9am'].fillna(df_albury['WindDir9am'].mode(),inplace=True)
df_albury['WindDir3pm'].fillna(df_albury['WindDir3pm'].mode(),inplace=True)
df_albury['WindSpeed9am'].fillna(df_albury['WindSpeed9am'].median(),inplace=True)
df_albury['WindSpeed3pm'].fillna(df_albury['WindSpeed3pm'].median(),inplace=True)
df_albury['Humidity9am'].fillna(df_albury['Humidity9am'].median(),inplace=True)
df_albury['Humidity3pm'].fillna(df_albury['Humidity3pm'].median(),inplace=True)
df_albury['Pressure3pm'].fillna(df_albury['Pressure3pm'].median(),inplace=True)
# Out:
# C:\Users\Cornelis\Anaconda3\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(df_albury[data_num].drop(columns=['RainTomorrow']),df_albury[data_num].RainTomorrow,test_size = 0.3)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report,confusion_matrix,log_loss,matthews_corrcoef

pipe_knn = Pipeline([('std_scl', StandardScaler()), 
                    ('pca', PCA(n_components=10)),
                    ('knn', KNeighborsClassifier(n_neighbors=10))])

pipe_knn.fit(X_train, y_train)

print('Test Accuracy: %.3f' % pipe_knn.score(X_test, y_test))
train_pred=pipe_knn.predict(X_train)
knn_pred=pipe_knn.predict(X_test)
knn_predprob=pipe_knn.predict_proba(X_test)
print('Logloss: %.3f' %log_loss(y_test,knn_predprob))
print(classification_report(y_train,train_pred))
print(confusion_matrix(y_train,train_pred))
print(classification_report(y_test,knn_pred))
print(confusion_matrix(y_test,knn_pred))
# Out:
# Test Accuracy: 0.905
# Logloss: 0.740
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.94      1694
#            1       0.98      0.52      0.68       413
#
#     accuracy                           0.90      2107
#    macro avg       0.94      0.76      0.81      2107
# weighted avg       0.91      0.90      0.89      2107
#
# [[1689    5]
#  [ 197  216]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94       699
#            1       0.95      0.61      0.75       205
#
#     accuracy                           0.90       904
#    macro avg       0.92      0.80      0.84       904
# weighted avg       0.91      0.90      0.90       904
#
# [[692   7]
#  [ 79 126]]

# %%
# log_loss(knn_predprob,y_test)
knn_predprob
# Out:
# array([[1. , 0. ],
#        [0.4, 0.6],
#        [0.6, 0.4],
#        ...,
#        [1. , 0. ],
#        [1. , 0. ],
#        [1. , 0. ]])

# %%
pipe_rfc = Pipeline([('std_scl', StandardScaler()), 
                    ('pca', PCA(n_components=10)),
                    ('rfc', RandomForestClassifier(n_estimators=100,criterion='gini',n_jobs=-1))])

pipe_rfc.fit(X_train, y_train)

print('Test Accuracy: %.3f' % pipe_rfc.score(X_test, y_test))
pred_rfc=pipe_rfc.predict(X_test)
predprob_rfc=pipe_rfc.predict_proba(X_test)
train_pred=pipe_rfc.predict(X_train)
print('Logloss: %.3f' %log_loss(y_test,predprob_rfc))
print(classification_report(y_train,train_pred))
print(confusion_matrix(y_train,train_pred))
print(classification_report(y_test,pred_rfc))
print(confusion_matrix(y_test,pred_rfc))
# Out:
# Test Accuracy: 0.934
# Logloss: 0.212
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1694
#            1       1.00      1.00      1.00       413
#
#     accuracy                           1.00      2107
#    macro avg       1.00      1.00      1.00      2107
# weighted avg       1.00      1.00      1.00      2107
#
# [[1694    0]
#  [   0  413]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       699
#            1       0.91      0.78      0.84       205
#
#     accuracy                           0.93       904
#    macro avg       0.93      0.88      0.90       904
# weighted avg       0.93      0.93      0.93       904
#
# [[684  15]
#  [ 45 160]]

# %%
pipe_xgb = Pipeline([('std_scl', StandardScaler()), 
                    ('pca', PCA(n_components=10)),
                    ('xgb', XGBClassifier(n_estimators=2,learning_rate=0.1,n_jobs=-1))])

pipe_xgb.fit(X_train, y_train)

print('Test Accuracy: %.3f' % pipe_xgb.score(X_test, y_test))
train_pred=pipe_xgb.predict(X_train)
pred_xgb=pipe_xgb.predict(X_test)
predprob_xgb=pipe_xgb.predict_proba(X_test)
print('Logloss: %.3f' %log_loss(y_test,predprob_xgb))
print(classification_report(y_train,train_pred))
print(confusion_matrix(y_train,train_pred))
print(classification_report(y_test,pred_xgb))
print(confusion_matrix(y_test,pred_xgb))
# Out:
# Test Accuracy: 0.910
# Logloss: 0.572
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95      1694
#            1       0.91      0.63      0.74       413
#
#     accuracy                           0.92      2107
#    macro avg       0.91      0.81      0.85      2107
# weighted avg       0.91      0.92      0.91      2107
#
# [[1668   26]
#  [ 153  260]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94       699
#            1       0.92      0.66      0.77       205
#
#     accuracy                           0.91       904
#    macro avg       0.92      0.82      0.86       904
# weighted avg       0.91      0.91      0.90       904
#
# [[688  11]
#  [ 70 135]]

# %%
from sklearn.model_selection import GridSearchCV

param_learning = np.linspace(0.1,1,10)
param_estimator = (2,5,7,10,12)
param_grid = {'learning_rate': param_learning, 'n_estimators':param_estimator}

gs = GridSearchCV(pipe_xgb.steps[2][1],param_grid,scoring='accuracy')

# Training and searching hyper parameter space and evaluating model
# by using cross validation logic folded into 10
gs = gs.fit(X_train, y_train)

print(gs.best_score_)
print(gs.best_params_)
# Out:
# C:\Users\Cornelis\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# 1.0
# {'learning_rate': 0.1, 'n_estimators': 2}

# %%
param_neighbors = (10,30,50,70,90)
param_grid = {'n_neighbors':param_neighbors}

gs = GridSearchCV(pipe_knn.steps[2][1],param_grid,scoring='accuracy')

# Training and searching hyper parameter space and evaluating model
# by using cross validation logic folded into 10
gs = gs.fit(X_train, y_train)

print(gs.best_score_)
print(gs.best_params_)
# Out:
# C:\Users\Cornelis\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# 0.8775510204081632
# {'n_neighbors': 10}

# %%
# param_learning = np.linspace(0.1,1,10)
param_estimator = (100,150,200,250,300)
param_grid = {'n_estimators':param_estimator}

gs = GridSearchCV(pipe_rfc.steps[2][1],param_grid,scoring='accuracy')

# Training and searching hyper parameter space and evaluating model
# by using cross validation logic folded into 10
gs = gs.fit(X_train, y_train)

print(gs.best_score_)
print(gs.best_params_)
# Out:
# C:\Users\Cornelis\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# 1.0
# {'n_estimators': 100}
